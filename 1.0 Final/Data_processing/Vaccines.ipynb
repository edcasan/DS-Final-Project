# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
vaccines = "../Resources/country_vaccinations.csv"

# %%
vaccines_df = pd.read_csv(vaccines)

# %%
vaccines_df.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                            0.00                           0.00
# 1                             NaN                            NaN
# 2                            0.00                           0.00
# 3                            0.01                           0.01
# 4                            0.01                           0.01
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            22.0
# 2                                  NaN                            22.0
# 3                                  NaN                            22.0
# 4                                  NaN                            23.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
# 1  Pfizer/BioNTech  Ministry of Health
# 2  Pfizer/BioNTech  Ministry of Health
# 3  Pfizer/BioNTech  Ministry of Health
# 4  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website
# 0  https://shendetesia.gov.al/covid19-ministria-e...
# 1  https://shendetesia.gov.al/covid19-ministria-e...
# 2  https://shendetesia.gov.al/covid19-ministria-e...
# 3  https://shendetesia.gov.al/covid19-ministria-e...
# 4  https://shendetesia.gov.al/covid19-ministria-e...

# %%
del vaccines_df['iso_code']
del vaccines_df['daily_vaccinations_raw']
del vaccines_df['total_vaccinations_per_hundred']
del vaccines_df['people_vaccinated_per_hundred']
del vaccines_df['people_fully_vaccinated_per_hundred']
del vaccines_df['daily_vaccinations_per_million']
del vaccines_df['source_name']
del vaccines_df['source_website']

# %%
vaccines_df.head()
# Out:
#    country        date  total_vaccinations  people_vaccinated  \
# 0  Albania  2021-01-10                 0.0                0.0
# 1  Albania  2021-01-11                 NaN                NaN
# 2  Albania  2021-01-12               128.0              128.0
# 3  Albania  2021-01-13               188.0              188.0
# 4  Albania  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations         vaccines
# 0                      NaN                 NaN  Pfizer/BioNTech
# 1                      NaN                64.0  Pfizer/BioNTech
# 2                      NaN                64.0  Pfizer/BioNTech
# 3                      NaN                63.0  Pfizer/BioNTech
# 4                      NaN                66.0  Pfizer/BioNTech

# %%
vaccines_df = vaccines_df[vaccines_df['daily_vaccinations'].notna()]
vaccines_df
# Out:
#        country        date  total_vaccinations  people_vaccinated  \
# 1      Albania  2021-01-11                 NaN                NaN
# 2      Albania  2021-01-12               128.0              128.0
# 3      Albania  2021-01-13               188.0              188.0
# 4      Albania  2021-01-14               266.0              266.0
# 5      Albania  2021-01-15               308.0              308.0
# ...        ...         ...                 ...                ...
# 5452  Zimbabwe  2021-03-03             27970.0            27970.0
# 5453  Zimbabwe  2021-03-04             30658.0            30658.0
# 5454  Zimbabwe  2021-03-05             31325.0            31325.0
# 5455  Zimbabwe  2021-03-06             32014.0            32014.0
# 5456  Zimbabwe  2021-03-07             32240.0            32240.0
#
#       people_fully_vaccinated  daily_vaccinations           vaccines
# 1                         NaN                64.0    Pfizer/BioNTech
# 2                         NaN                64.0    Pfizer/BioNTech
# 3                         NaN                63.0    Pfizer/BioNTech
# 4                         NaN                66.0    Pfizer/BioNTech
# 5                         NaN                62.0    Pfizer/BioNTech
# ...                       ...                 ...                ...
# 5452                      NaN              2871.0  Sinopharm/Beijing
# 5453                      NaN              2807.0  Sinopharm/Beijing
# 5454                      NaN              2678.0  Sinopharm/Beijing
# 5455                      NaN              2330.0  Sinopharm/Beijing
# 5456                      NaN              1914.0  Sinopharm/Beijing
#
# [5269 rows x 7 columns]

# %%
vaccines_df.to_csv("clean_vaccines.csv",encoding="UTF-8")

# %%
world_vaccine = vaccines_df.groupby(["country"])

# %%
total_country_vacc = pd.DataFrame({
    "Total Vaccinations": world_vaccine['daily_vaccinations'].sum()
       
})
total_country_vacc
# Out:
#                Total Vaccinations
# country
# Albania                   13323.0
# Algeria                   69070.0
# Andorra                    1971.0
# Anguilla                   4083.0
# Argentina               1313391.0
# ...                           ...
# United States          82977935.0
# Uruguay                   66784.0
# Venezuela                  8704.0
# Wales                   1095232.0
# Zimbabwe                  29937.0
#
# [126 rows x 1 columns]

# %%
top_countries_df = total_country_vacc.sort_values(by="Total Vaccinations",ascending=False)
top_countries_df
# Out:
#                      Total Vaccinations
# country
# United States                82977935.0
# China                        49687760.0
# United Kingdom               22248026.0
# England                      18769920.0
# India                        18545913.0
# ...                                 ...
# Egypt                            1314.0
# Belize                           1043.0
# Montserrat                        645.0
# Trinidad and Tobago               441.0
# Grenada                           145.0
#
# [126 rows x 1 columns]

# %%
#connection_string = "postgres://postgres:12@localhost/vaccines"
#conn = create_engine(connection_string)

# %%
#vaccines_df.to_sql(name="countries", con=conn, if_exists="replace", index=False)
